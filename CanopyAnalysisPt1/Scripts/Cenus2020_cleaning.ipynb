# %%
#!pip install rioxarray
import dask.array as da
import pystac_client
from pystac_client import Client
import leafmap
from datetime import datetime
import dask
import planetary_computer as pc
import geogif
import numpy as np
import xarray as xr
import rioxarray
import geopandas as gpd
import matplotlib.pyplot as plt
import geojson
import json
from geogif import dgif, gif
import pandas as pd
import shapely
from shapely.geometry import mapping
from shapely.geometry import box
import folium
from pystac import ItemCollection
from pyproj import CRS
from branca.colormap import LinearColormap

# %%
# Read the shapefiles in as GeoDataFrames
countyCensus = gpd.read_file('CorrectWorcester.shp')
boundary = gpd.read_file('Boundary/WorcesterBoundary.shp')

# %%
# Check CRSs
print(boundary.crs)
print(countyCensus.crs)
# Out:
# EPSG:3585
# EPSG:3857

# %%
# We'll probably go with 3857 as the CRS to work in here, as it is preferable for web mapping
# Reproject the boundary layer to EPSG:3857
boundary = boundary.to_crs(epsg=3857)

# %%
# Clip countyCensus to the city boundary
worcester2020Census = gpd.clip(countyCensus, boundary)

# %%
# # Lets check out worcesterCensus
# print((worcester2020Census.columns).tolist())

# %%
# It has a lot of columns, most of which are, for the purposes of this project, unecessary
# Rename the ones we need
# I am referencing https://www.arcgis.com/home/item.html?id=abd94a6cc94645f88811ae91802909a0
# and the column aliases as vieweD in the attribute table

# Mapping of old column names to new column names
column_mapping = {
    'P0010001': 'Total Pop',
    'P0010002': 'One race',
    'P0010003': 'White alone',
    'P0010004': 'Black',
    'P0010005': 'American Indian',
    'P0010006': 'Asian',
    'P0010007': 'Pacific Islander',
    'P0010008': 'Other Race',
    'P0020002': 'Hispanic',
    'PCT_P00300': 'Percent 18 Years and Over',
    'PCT_P00200': 'Percent Hispanic',
    'PCT_P002_1': 'Percent White',
    'PCT_P002_2': 'Percent Black',
    'PCT_P002_3': 'Percent American Indian',
    'PCT_P002_4': 'Percent Asian',
    'PCT_P002_5': 'Percent Pacific Islander',
    'PCT_P002_6': 'Percent Other Race',
    'PCT_P002_7': 'Percent two or more races',
    'PCT_H00100': 'Percent of Housing Occupied',
    'PCT_H001_1': 'Percent of Housing Vacant'
}

# Rename columns
worcester2020Census = worcester2020Census.rename(columns=column_mapping)

# %%
# Now lets get rid of unecessary columns
# Filter out columns that start with "P00"
columns_to_keep = [col for col in worcester2020Census.columns if not (col.startswith('P00') or col.startswith('H00'))]

# Select only the columns you want to keep
worcester2020Census = worcester2020Census[columns_to_keep]

# %%
print((worcester2020Census.columns).tolist())
# Out:
# ['GEOID', 'NAME', 'County_Nam', 'State_Name', 'Total Pop', 'One race', 'White alone', 'Black', 'American Indian', 'Asian', 'Pacific Islander', 'Other Race', 'Hispanic', 'Percent 18 Years and Over', 'Percent Hispanic', 'Percent White', 'Percent Black', 'Percent American Indian', 'Percent Asian', 'Percent Pacific Islander', 'Percent Other Race', 'Percent two or more races', 'Percent of Housing Occupied', 'Percent of Housing Vacant', 'SUMLEV', 'REGION', 'DIVISION', 'STATE', 'STATENS', 'COUNTY', 'COUNTYCC', 'COUNTYNS', 'COUSUB', 'COUSUBCC', 'COUSUBNS', 'SUBMCD', 'SUBMCDCC', 'SUBMCDNS', 'ESTATE', 'ESTATECC', 'ESTATENS', 'CONCIT', 'CONCITCC', 'CONCITNS', 'PLACE', 'PLACECC', 'PLACENS', 'TRACT', 'AIANHH', 'AIHHTLI', 'AIANHHFP', 'AIANHHCC', 'AIANHHNS', 'AITS', 'AITSFP', 'AITSCC', 'AITSNS', 'TTRACT', 'ANRC', 'ANRCCC', 'ANRCNS', 'CBSA', 'MEMI', 'CSA', 'METDIV', 'NECTA', 'NMEMI', 'CNECTA', 'NECTADIV', 'CBSAPCI', 'NECTAPCI', 'UA', 'UATYPE', 'UR', 'CD116', 'SLDU18', 'SLDL18', 'VTD', 'VTDI', 'ZCTA', 'SDELM', 'SDSEC', 'SDUNI', 'PUMA', 'AREALAND', 'AREAWATR', 'AWATER', 'ALAND', 'INTPTLON', 'INTPTLAT', 'BASENAME', 'FUNCSTAT', 'GCUNI', 'POP100', 'HU100', 'PARTFLAG', 'UGA', 'Shape__Are', 'Shape__Len', 'geometry']

# %%
# Get rid of More columns
columns_to_delete = ['County_Nam', 'State_Name','SUMLEV', 'REGION', 'DIVISION', 'STATE', 'STATENS', 'COUNTY', 'COUNTYCC', 'COUNTYNS', 'COUSUB', 'COUSUBCC', 'COUSUBNS', 'SUBMCD', 'SUBMCDCC', 'SUBMCDNS', 'ESTATE', 'ESTATECC', 'ESTATENS', 'CONCIT', 'CONCITCC', 'CONCITNS', 'PLACE', 'PLACECC', 'PLACENS', 'TRACT', 'AIANHH', 'AIHHTLI', 'AIANHHFP', 'AIANHHCC', 'AIANHHNS', 'AITS', 'AITSFP', 'AITSCC', 'AITSNS', 'TTRACT', 'ANRC', 'ANRCCC', 'ANRCNS', 'CBSA', 'MEMI', 'CSA', 'METDIV', 'NECTA', 'NMEMI', 'CNECTA', 'NECTADIV', 'CBSAPCI', 'NECTAPCI', 'UA', 'UATYPE', 'UR', 'CD116', 'SLDU18', 'SLDL18', 'VTD', 'VTDI', 'ZCTA', 'SDELM', 'SDSEC', 'SDUNI', 'PUMA', 'AREALAND', 'AREAWATR', 'AWATER', 'ALAND', 'INTPTLON', 'INTPTLAT', 'BASENAME', 'FUNCSTAT', 'GCUNI', 'POP100', 'HU100', 'PARTFLAG', 'UGA', 'Percent 18 Years and Over', 'Percent two or more races', 'Percent of Housing Occupied', 'Percent of Housing Vacant', 'NAME','Shape__Are', 'Shape__Len',]

worcester2020Census = worcester2020Census.drop(columns=columns_to_delete)

# %%
print((worcester2020Census.columns).tolist())
# Out:
# ['GEOID', 'Total Pop', 'One race', 'White alone', 'Black', 'American Indian', 'Asian', 'Pacific Islander', 'Other Race', 'Hispanic', 'Percent Hispanic', 'Percent White', 'Percent Black', 'Percent American Indian', 'Percent Asian', 'Percent Pacific Islander', 'Percent Other Race', 'geometry']

# %%
# create a nice 'Tract' column
worcester2020Census['GEOID'] = worcester2020Census['GEOID'].astype(str)

# Extract the last 6 digits of each 'GEOID' and assign it to the 'Tract' column
worcester2020Census['Tract'] = worcester2020Census['GEOID'].str[-6:]

# %%
# 'Tract' is now the common identifier between 2010 and 2020, so we can get rid of GEOID
worcester2020Census = worcester2020Census.drop(columns='GEOID')

# %%
worcester2020Census.sort_values(by='Tract')
# Out:
#      Total Pop  One race  White alone  Black  American Indian  Asian  \
# 58        5004      4719         4290    190               11     73
# 91        5388      5083         4646    101               17    245
# 92        4045      3833         3553     80                2    139
# 129       5008      4802         4353    227                5    117
# 130       2869      2657         2473     66                4     32
# ..         ...       ...          ...    ...              ...    ...
# 88        5381      5055         4744    119                5    130
# 90        6690      6299         5675    189                9    298
# 133       5286      4958         3433     54                4   1361
# 139       7945      7477         5837    116               14   1395
# 148       3436      3221         2850     90                3    179
#
#      Pacific Islander  Other Race  Hispanic  Percent Hispanic  Percent White  \
# 58                  1         154       303               6.1           84.9
# 91                  2          72       249               4.6           85.3
# 92                  0          59       155               3.8           86.6
# 129                 1          99       380               7.6           82.2
# 130                 0          82       203               7.1           84.5
# ..                ...         ...       ...               ...            ...
# 88                  4          53       227               4.2           86.9
# 90                  1         127       290               4.3           83.8
# 133                 0         106       220               4.2           64.1
# 139                 4         111       300               3.8           73.0
# 148                 1          98       204               5.9           81.9
#
#      Percent Black  Percent American Indian  Percent Asian  \
# 58             3.5                      0.2            1.4
# 91             1.8                      0.1            4.5
# 92             2.0                      0.0            3.3
# 129            4.2                      0.1            2.3
# 130            1.9                      0.0            1.0
# ..             ...                      ...            ...
# 88             2.0                      0.1            2.4
# 90             2.7                      0.0            4.4
# 133            0.8                      0.0           25.7
# 139            1.4                      0.1           17.6
# 148            2.6                      0.0            5.2
#
#      Percent Pacific Islander  Percent Other Race  \
# 58                        0.0                 0.8
# 91                        0.0                 0.2
# 92                        0.0                 0.5
# 129                       0.0                 0.7
# 130                       0.0                 0.7
# ..                        ...                 ...
# 88                        0.1                 0.3
# 90                        0.0                 0.7
# 133                       0.0                 1.0
# 139                       0.0                 0.6
# 148                       0.0                 0.7
#
#                                               geometry   Tract
# 58   MULTIPOLYGON (((-8001131.688 5204000.758, -800...  727100
# 91   POLYGON ((-8001114.990 5204014.601, -8001131.6...  728100
# 92   POLYGON ((-7995293.535 5208823.946, -7995374.3...  728200
# 129  POLYGON ((-7989207.029 5207720.620, -7989287.5...  729100
# 130  POLYGON ((-7991198.981 5212202.166, -7991250.9...  729200
# ..                                                 ...     ...
# 88   POLYGON ((-7992411.027 5192486.506, -7992417.3...  737100
# 90   POLYGON ((-7990857.785 5193411.299, -7990858.8...  737300
# 133  MULTIPOLYGON (((-7985084.866 5197193.020, -798...  739101
# 139  POLYGON ((-7989207.029 5207720.620, -7989200.5...  739500
# 148  POLYGON ((-7985084.866 5197193.020, -7985084.4...  761300
#
# [61 rows x 18 columns]

# %%
# hmm, 2010 census only has 60 tracts
worcester2020Census['Tract'].nunique()
# Out:
# 61

# %%
# Lets visualize to investigate
# To visualize this data we have to reproject to 4326, which is the best CRS for folium
worcester2020Census4326 = worcester2020Census.to_crs(epsg=4326)

# %%
import folium

# Create a Folium map
m = folium.Map(location=[42.2626, -71.8023], zoom_start=10)
colormap = LinearColormap(colors=['green', 'white'], vmin=17.7, vmax=88.7)

# Iterate over the rows of the worcesterCensus4326 GeoDataFrame and add polygons to the map with color based on the "Percent White" column
for idx, row in worcester2020Census4326.iterrows():
    # Check the value of "Percent White" for the current row
    print(f"Census Tract: {row['Tract']}, Percent White: {row['Percent White']}")
    
    # Style function for GeoJSON features
    style_function = lambda x, row=row: {
        'fillColor': colormap(row['Percent White']),
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.7
    }
    # Add GeoJSON feature to the map
    #folium.GeoJson(row.geometry.__geo_interface__, style_function=style_function).add_to(m)
    # Add GeoJSON feature to the map with tooltip showing "Percent White" value
    
    folium.GeoJson(row.geometry.__geo_interface__, 
                   style_function=style_function,
                   tooltip=f"Census Tract: {row['Tract']}<br>Percent White: {row['Percent White']}").add_to(m)
    
#folium.GeoJson(combined_gdf.geometry).add_to(m)
# Display the map
m
# Out:
# Census Tract: 737300, Percent White: 83.8
# Census Tract: 732801, Percent White: 61.3
# Census Tract: 761300, Percent White: 81.9
# Census Tract: 732301, Percent White: 62.5
# Census Tract: 737100, Percent White: 86.9
# Census Tract: 736400, Percent White: 83.6
# Census Tract: 732901, Percent White: 49.4
# Census Tract: 732802, Percent White: 49.0
# Census Tract: 732902, Percent White: 68.9
# Census Tract: 732700, Percent White: 34.1
# Census Tract: 733000, Percent White: 26.3
# Census Tract: 732600, Percent White: 31.2
# Census Tract: 731300, Percent White: 17.7
# Census Tract: 732302, Percent White: 47.6
# Census Tract: 739101, Percent White: 64.1
# Census Tract: 732202, Percent White: 60.0
# Census Tract: 732201, Percent White: 55.6
# Census Tract: 732002, Percent White: 53.7
# Census Tract: 731900, Percent White: 28.8
# Census Tract: 730402, Percent White: 38.6
# Census Tract: 730500, Percent White: 50.0
# Census Tract: 730401, Percent White: 40.3
# Census Tract: 730300, Percent White: 64.6
# Census Tract: 730200, Percent White: 67.9
# Census Tract: 730100, Percent White: 61.8
# Census Tract: 728200, Percent White: 86.6
# Census Tract: 729200, Percent White: 84.5
# Census Tract: 729100, Percent White: 82.2
# Census Tract: 739500, Percent White: 73.0
# Census Tract: 732001, Percent White: 20.2
# Census Tract: 736500, Percent White: 88.7
# Census Tract: 736300, Percent White: 82.6
# Census Tract: 736200, Percent White: 83.8
# Census Tract: 733101, Percent White: 58.5
# Census Tract: 733102, Percent White: 52.1
# Census Tract: 735200, Percent White: 75.6
# Census Tract: 731204, Percent White: 26.5
# Census Tract: 731203, Percent White: 32.9
# Census Tract: 731202, Percent White: 72.4
# Census Tract: 732500, Percent White: 32.6
# Census Tract: 732400, Percent White: 28.4
# Census Tract: 731400, Percent White: 19.4
# Census Tract: 731500, Percent White: 25.3
# Census Tract: 731700, Percent White: 47.7
# Census Tract: 732203, Percent White: 41.3
# Census Tract: 731802, Percent White: 22.5
# Census Tract: 731801, Percent White: 51.7
# Census Tract: 731601, Percent White: 51.0
# Census Tract: 731602, Percent White: 65.5
# Census Tract: 731002, Percent White: 45.9
# Census Tract: 731101, Percent White: 41.4
# Census Tract: 731001, Percent White: 51.1
# Census Tract: 731102, Percent White: 61.7
# Census Tract: 730902, Percent White: 72.3
# Census Tract: 730901, Percent White: 77.4
# Census Tract: 730802, Percent White: 73.7
# Census Tract: 730801, Percent White: 78.6
# Census Tract: 730700, Percent White: 68.1
# Census Tract: 730600, Percent White: 78.5
# Census Tract: 727100, Percent White: 84.9
# Census Tract: 728100, Percent White: 85.3
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f202b58c048cd02c07b2f94437189a4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f202b58c048cd02c07b2f94437189a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f202b58c048cd02c07b2f94437189a4a = L.map(
#                 &quot;map_f202b58c048cd02c07b2f94437189a4a&quot;,
#                 {
#                     center: [42.2626, -71.8023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd9736aa6c9f1b0e332b4cd230d10010 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dd9736aa6c9f1b0e332b4cd230d10010.addTo(map_f202b58c048cd02c07b2f94437189a4a);
#
#
#         function geo_json_c20d23a9b0a41b59c33b0433b51bf3eb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eef7eeff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c20d23a9b0a41b59c33b0433b51bf3eb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c20d23a9b0a41b59c33b0433b51bf3eb = L.geoJson(null, {
#                 onEachFeature: geo_json_c20d23a9b0a41b59c33b0433b51bf3eb_onEachFeature,
#
#                 style: geo_json_c20d23a9b0a41b59c33b0433b51bf3eb_styler,
#         });
#
#         function geo_json_c20d23a9b0a41b59c33b0433b51bf3eb_add (data) {
#             geo_json_c20d23a9b0a41b59c33b0433b51bf3eb
#                 .addData(data);
#         }
#             geo_json_c20d23a9b0a41b59c33b0433b51bf3eb_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.78309681940122, 42.21613962233172], [-71.78310681944697, 42.21620262279509], [-71.78030381884234, 42.217433622764], [-71.78012381891728, 42.217510623000656], [-71.77982581899145, 42.21764262271272], [-71.77891281804905, 42.21804162329479], [-71.77870481853492, 42.218133622974655], [-71.77594781706274, 42.21934262333559], [-71.77520281724817, 42.21966962313908], [-71.76897381552475, 42.22240262434563], [-71.76539581407002, 42.223970624364654], [-71.76519381440364, 42.22405962456522], [-71.76171281303327, 42.22558562487726], [-71.7596538124183, 42.226488625025624], [-71.7519258099466, 42.22987762589546], [-71.75188381011381, 42.22989662622632], [-71.74535680846456, 42.23275862667634], [-71.74523280861601, 42.23281262664228], [-71.74265380741906, 42.23394262720324], [-71.74098780716449, 42.23467162745962], [-71.73885447480468, 42.23560648247541], [-71.74097597066539, 42.23461400102767], [-71.74159797031834, 42.23434700086464], [-71.7422699703127, 42.2340360010065], [-71.74254197000896, 42.2339120001292], [-71.74254197083472, 42.23390999964954], [-71.74530997158564, 42.232711000110164], [-71.74532397164377, 42.23275899967714], [-71.74535697216575, 42.232749999907426], [-71.74670897333273, 42.23215300008089], [-71.74684297272378, 42.232090999626834], [-71.74994897454184, 42.230723998432], [-71.7518439722372, 42.22986800076188], [-71.75192797288058, 42.22984800066914], [-71.75192797219876, 42.229846000190584], [-71.75341297250517, 42.22919900120243], [-71.75511797133295, 42.22844800201157], [-71.75750497001076, 42.227397004656304], [-71.75963497080672, 42.226462006036826], [-71.76169896902145, 42.22555100775981], [-71.76343496746159, 42.224787009199446], [-71.76517296840115, 42.22402001033491], [-71.76537596758116, 42.22393101025454], [-71.76697696655346, 42.22322801084423], [-71.76894996623207, 42.2223640132459], [-71.7709959654451, 42.221459015239574], [-71.77304996470971, 42.22055401545094], [-71.77516596259817, 42.21961901714224], [-71.77592896340668, 42.21928701752739], [-71.77849996140817, 42.218151018960754], [-71.77887896164214, 42.21798801947891], [-71.77981796152874, 42.21757501979271], [-71.78033196037207, 42.21735501984563], [-71.78310121309568, 42.216128896612936], [-71.78309681940122, 42.21613962233172]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_c20d23a9b0a41b59c33b0433b51bf3eb.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract: 737300&lt;br&gt;Percent White: 83.8
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             geo_json_c20d23a9b0a41b59c33b0433b51bf3eb.addTo(map_f202b58c048cd02c07b2f94437189a4a);
#
#
#         function geo_json_a1f49df4535a0b6f6d86edd89a1087bb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9dce9dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};

# %%
# Looks like Tract 731600, right in the middle of Worcester, was split along Highland Street into 731601 and 731602,

# In order to compare 2020 with 2010 we will have to merge these back into one.

# Filter rows for Tract 731601 and Tract 731602
tract_731601 = worcester2020Census4326[worcester2020Census4326['Tract'] == '731601']
tract_731602 = worcester2020Census4326[worcester2020Census4326['Tract'] == '731602']

# Extract geometry
t1 = tract_731601['geometry']
t2 = tract_731602['geometry']
# Concatenate
combined_rows = pd.concat([t1, t2], ignore_index=True)
# Unify
combined = combined_rows.unary_union
combined_gdf = gpd.GeoDataFrame(geometry=[combined])
combined_gdf= combined_gdf.set_crs("EPSG:4326")
print(type(combined_gdf))
combined_gdf
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#                                             geometry
# 0  POLYGON ((-71.81752 42.26785, -71.81746 42.268...

# %%
tract_731601
# Out:
#      Total Pop  One race  White alone  Black  American Indian  Asian  \
# 107       4812      4252         2637    516               28    583
#
#      Pacific Islander  Other Race  Hispanic  Percent Hispanic  Percent White  \
# 107                 2         486      1022              21.2           51.0
#
#      Percent Black  Percent American Indian  Percent Asian  \
# 107           10.0                      0.3           12.1
#
#      Percent Pacific Islander  Percent Other Race  \
# 107                       0.0                 1.1
#
#                                               geometry   Tract
# 107  POLYGON ((-71.81767 42.26747, -71.81752 42.267...  731601

# %%
# Create a dictionary to store the sums of each column
sums = {}

# List of columns to sum
columns_to_sum = ['Total Pop', 'One race', 'White alone', 'Black', 'American Indian', 'Asian', 'Pacific Islander', 'Other Race', 'Hispanic']

# Iterate over each column and calculate the sum
for column in columns_to_sum:
    sums[column] = tract_731601[column].sum() + tract_731602[column].sum()

# Add the sums as new columns to combined_gdf
for column, value in sums.items():
    combined_gdf[column] = value

# Print the updated combined_gdf
combined_gdf
# Out:
#                                             geometry  Total Pop  One race  \
# 0  POLYGON ((-71.81752 42.26785, -71.81746 42.268...       8079      7340
#
#    White alone  Black  American Indian  Asian  Pacific Islander  Other Race  \
# 0         4906    887               31    887                 2         627
#
#    Hispanic
# 0      1376

# %%
total_pop = combined_gdf['Total Pop']
combined_gdf['Percent Hispanic'] = ((combined_gdf['Hispanic'] / total_pop) * 100).round(2)
combined_gdf['Percent White'] = ((combined_gdf['White alone'] / total_pop) * 100).round(2)
combined_gdf['Percent Black'] = ((combined_gdf['Black'] / total_pop) * 100).round(2)
combined_gdf['Percent American Indian'] = ((combined_gdf['American Indian'] / total_pop) * 100).round(2)
combined_gdf['Percent Asian'] = ((combined_gdf['Asian'] / total_pop) * 100).round(2)
combined_gdf['Percent Pacific Islander'] = ((combined_gdf['Pacific Islander'] / total_pop) * 100).round(2)
combined_gdf['Percent Other Race'] = ((combined_gdf['Other Race'] / total_pop) * 100).round(2)
combined_gdf['Tract'] = '731600'

# %%
type(combined_gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Ok, looks like it's good to go
combined_gdf
# Out:
#                                             geometry  Total Pop  One race  \
# 0  POLYGON ((-71.81752 42.26785, -71.81746 42.268...       8079      7340
#
#    White alone  Black  American Indian  Asian  Pacific Islander  Other Race  \
# 0         4906    887               31    887                 2         627
#
#    Hispanic  Percent Hispanic  Percent White  Percent Black  \
# 0      1376             17.03          60.73          10.98
#
#    Percent American Indian  Percent Asian  Percent Pacific Islander  \
# 0                     0.38          10.98                      0.02
#
#    Percent Other Race   Tract
# 0                7.76  731600

# %%
# First drop the old subdivided tracts
worcester2020Census4326 = worcester2020Census4326.drop(tract_731601.index)
worcester2020Census4326 = worcester2020Census4326.drop(tract_731602.index)

# %%
Census4326 = pd.concat([worcester2020Census4326, combined_gdf], ignore_index=True)

# %%
Census4326.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
Census4326['Tract'].nunique()
# Out:
# 60

# %%
Census4326
# Out:
#     Total Pop  One race  White alone  Black  American Indian  Asian  \
# 0        6690      6299         5675    189                9    298
# 1        5374      4901         3425    836               10    323
# 2        3436      3221         2850     90                3    179
# 3        4835      4383         3123    703               16    296
# 4        5381      5055         4744    119                5    130
# 5        3113      2930         2656     92                5    125
# 6        7444      6510         3944   1420               32    349
# 7        4620      4139         2425   1003                8    353
# 8        3299      3193         2470    227                0    345
# 9        4699      4158         1921   1206               27    191
# 10       4273      3629         1348    622               17    705
# 11       5448      4632         2028   1064               29    202
# 12       4423      3739         1123    670               25    420
# 13       4716      4108         2464    821               23    246
# 14       5286      4958         3433     54                4   1361
# 15       3683      3200         2305    364               30    235
# 16       3264      2977         1894    467               17    325
# 17       4348      3976         2514    637                8    545
# 18       6351      5401         2350   1321               87    322
# 19       2066      1778          915    339               17    153
# 20       4166      3656         2192    836               17    142
# 21       5992      5336         2731   1524               21    202
# 22       5223      4793         3517    621               26    184
# 23       6146      5666         4333    648               18    345
# 24       6504      5933         4191   1011               12    343
# 25       4045      3833         3553     80                2    139
# 26       2869      2657         2473     66                4     32
# 27       5008      4802         4353    227                5    117
# 28       7945      7477         5837    116               14   1395
# 29       3439      2817         1095    609               28    112
# 30       4614      4337         4121     60                4    104
# 31       2489      2305         2098     55                0     67
# 32       3985      3741         3419     62                5    161
# 33       2273      2027         1397    226               11    195
# 34       2708      2463         1500    301                7    321
# 35       4442      4044         3445    236                6    120
# 36       2531      2206          839    346               21    357
# 37       6090      5179         2411    698               65    842
# 38       1375      1336         1064    214                1     25
# 39       2490      2184          954    319               21    229
# 40       8018      6748         2776   1591               75    344
# 41       5197      4330         1417    883               45    471
# 42       5443      4453         1805    918               56    249
# 43       4059      3652         2097    589               37    468
# 44       3212      2801         1476    559               13    311
# 45       4118      3274         1221    763               21    192
# 46       2825      2444         1580    253               11    236
# 47       7081      6239         3515   1129               22    765
# 48       4527      3905         2102    647               32    486
# 49       2468      2239         1315    494                4    258
# 50       2857      2602         1820    310               13    215
# 51       4416      4137         3332    404               10    227
# 52       3728      3443         2957    205                3    147
# 53       2222      2044         1685     96                6    112
# 54       3823      3530         3038    215                5    162
# 55       7367      6730         5180    814               15    363
# 56       9298      8866         7463    675               26    488
# 57       5004      4719         4290    190               11     73
# 58       5388      5083         4646    101               17    245
# 59       8079      7340         4906    887               31    887
#
#     Pacific Islander  Other Race  Hispanic  Percent Hispanic  Percent White  \
# 0                  1         127       290              4.30          83.80
# 1                  0         307       620             11.50          61.30
# 2                  1          98       204              5.90          81.90
# 3                  0         245       529             10.90          62.50
# 4                  4          53       227              4.20          86.90
# 5                  0          52       150              4.80          83.60
# 6                  0         765      1543             20.70          49.40
# 7                  0         350       783             16.90          49.00
# 8                  3         148       396             12.00          68.90
# 9                  4         809      1460             31.10          34.10
# 10                 2         935      1643             38.50          26.30
# 11                 7        1302      2242             41.20          31.20
# 12                 1        1500      2465             55.70          17.70
# 13                 0         554      1127             23.90          47.60
# 14                 0         106       220              4.20          64.10
# 15                 0         266       567             15.40          60.00
# 16                 0         274       398             12.20          55.60
# 17                 3         269       615             14.10          53.70
# 18                 9        1312      2545             40.10          28.80
# 19                 1         353       651             31.50          38.60
# 20                 1         468       740             17.80          50.00
# 21                 0         858      1747             29.20          40.30
# 22                 3         442       722             13.80          64.60
# 23                 0         322       661             10.80          67.90
# 24                 4         372       807             12.40          61.80
# 25                 0          59       155              3.80          86.60
# 26                 0          82       203              7.10          84.50
# 27                 1          99       380              7.60          82.20
# 28                 4         111       300              3.80          73.00
# 29                 7         966      1966             57.20          20.20
# 30                 0          48       166              3.60          88.70
# 31                 0          85       214              8.60          82.60
# 32                 0          94       229              5.70          83.80
# 33                 0         198       341             15.00          58.50
# 34                 0         334       535             19.80          52.10
# 35                 1         236       449             10.10          75.60
# 36                 2         641      1079             42.60          26.50
# 37                 1        1162      2438             40.00          32.90
# 38                 0          32       110              8.00          72.40
# 39                 4         657      1024             41.10          32.60
# 40                 0        1962      3302             41.20          28.40
# 41                 2        1512      2696             51.90          19.40
# 42                 2        1423      2660             48.90          25.30
# 43                 4         457       920             22.70          47.70
# 44                 1         441       834             26.00          41.30
# 45                 0        1077      2036             49.40          22.50
# 46                 2         362       637             22.50          51.70
# 47                 7         801      1597             22.60          45.90
# 48                 5         633      1438             31.80          41.40
# 49                 1         167       340             13.80          51.10
# 50                 0         244       458             16.00          61.70
# 51                 0         164       440             10.00          72.30
# 52                 0         131       349              9.40          77.40
# 53                 0         145       290             13.10          73.70
# 54                 0         110       280              7.30          78.60
# 55                 3         355       760             10.30          68.10
# 56                 0         214       569              6.10          78.50
# 57                 1         154       303              6.10          84.90
# 58                 2          72       249              4.60          85.30
# 59                 2         627      1376             17.03          60.73
#
#     Percent Black  Percent American Indian  Percent Asian  \
# 0            2.70                     0.00           4.40
# 1           15.00                     0.10           6.00
# 2            2.60                     0.00           5.20
# 3           14.30                     0.30           6.10
# 4            2.00                     0.10           2.40
# 5            3.00                     0.10           4.00
# 6           18.40                     0.10           4.60
# 7           20.80                     0.00           7.60
# 8            6.30                     0.00          10.50
# 9           23.80                     0.20           4.10
# 10          13.30                     0.30          16.50
# 11          18.00                     0.00           3.70
# 12          13.00                     0.30           9.50
# 13          16.60                     0.10           5.20
# 14           0.80                     0.00          25.70
# 15           9.50                     0.10           6.40
# 16          13.80                     0.30           9.90
# 17          14.20                     0.20          12.50
# 18          19.40                     0.20           4.90
# 19          15.20                     0.30           7.20
# 20          18.70                     0.20           3.40
# 21          23.70                     0.10           3.30
# 22          11.30                     0.20           3.50
# 23          10.10                     0.10           5.60
# 24          15.10                     0.20           5.20
# 25           2.00                     0.00           3.30
# 26           1.90                     0.00           1.00
# 27           4.20                     0.10           2.30
# 28           1.40                     0.10          17.60
# 29          14.80                     0.10           2.90
# 30           1.10                     0.10           2.30
# 31           2.00                     0.00           2.60
# 32           1.50                     0.00           4.00
# 33           9.60                     0.00           8.60
# 34          10.80                     0.20          11.80
# 35           5.00                     0.10           2.70
# 36          12.40                     0.00          14.10
# 37           9.60                     0.20          13.60
# 38          15.20                     0.10           1.70
# 39          11.60                     0.30           9.20
# 40          18.70                     0.30           4.10
# 41          15.40                     0.10           8.90
# 42          15.30                     0.30           4.60
# 43          13.10                     0.30          11.40
# 44          16.10                     0.10           9.60
# 45          16.70                     0.20           4.60
# 46           8.30                     0.30           8.20
# 47          14.60                     0.10          10.70
# 48          11.60                     0.10          10.70
# 49          19.60                     0.10          10.50
# 50           9.80                     0.10           7.40
# 51           8.40                     0.10           5.10
# 52           5.20                     0.00           3.90
# 53           4.10                     0.10           5.00
# 54           5.30                     0.10           4.20
# 55          10.80                     0.20           4.90
# 56           6.90                     0.20           5.20
# 57           3.50                     0.20           1.40
# 58           1.80                     0.10           4.50
# 59          10.98                     0.38          10.98
#
#     Percent Pacific Islander  Percent Other Race  \
# 0                       0.00                0.70
# 1                       0.00                1.50
# 2                       0.00                0.70
# 3                       0.00                1.20
# 4                       0.10                0.30
# 5                       0.00                0.40
# 6                       0.00                1.90
# 7                       0.00                1.60
# 8                       0.10                0.00
# 9                       0.00                2.00
# 10                      0.00                0.90
# 11                      0.10                1.80
# 12                      0.00                1.30
# 13                      0.00                1.40
# 14                      0.00                1.00
# 15                      0.00                1.80
# 16                      0.00                2.90
# 17                      0.10                1.10
# 18                      0.00                1.70
# 19                      0.00                1.80
# 20                      0.00                3.00
# 21                      0.00                0.90
# 22                      0.00                2.50
# 23                      0.00                1.20
# 24                      0.10                1.10
# 25                      0.00                0.50
# 26                      0.00                0.70
# 27                      0.00                0.70
# 28                      0.00                0.60
# 29                      0.00                0.80
# 30                      0.00                0.20
# 31                      0.00                0.30
# 32                      0.00                1.00
# 33                      0.00                2.10
# 34                      0.00                1.70
# 35                      0.00                1.00
# 36                      0.00                0.90
# 37                      0.00                0.50
# 38                      0.00                0.00
# 39                      0.20                1.30
# 40                      0.00                2.40
# 41                      0.00                0.80
# 42                      0.00                1.00
# 43                      0.10                0.80
# 44                      0.00                1.30
# 45                      0.00                1.50
# 46                      0.10                2.40
# 47                      0.10                1.40
# 48                      0.00                1.00
# 49                      0.00                0.50
# 50                      0.00                1.10
# 51                      0.00                0.50
# 52                      0.00                0.60
# 53                      0.00                0.80
# 54                      0.00                0.50
# 55                      0.00                0.90
# 56                      0.00                0.50
# 57                      0.00                0.80
# 58                      0.00                0.20
# 59                      0.02                7.76
#
#                                              geometry   Tract
# 0   POLYGON ((-71.78310 42.21614, -71.78311 42.216...  737300
# 1   POLYGON ((-71.77344 42.24704, -71.77342 42.247...  732801
# 2   POLYGON ((-71.73124 42.24129, -71.73123 42.241...  761300
# 3   POLYGON ((-71.78041 42.25085, -71.77988 42.250...  732301
# 4   POLYGON ((-71.79705 42.20999, -71.79711 42.210...  737100
# 5   MULTIPOLYGON (((-71.81964 42.23033, -71.81777 ...  736400
# 6   POLYGON ((-71.82528 42.22993, -71.82510 42.230...  732901
# 7   POLYGON ((-71.79223 42.23691, -71.79220 42.237...  732802
# 8   POLYGON ((-71.81283 42.24045, -71.81276 42.240...  732902
# 9   POLYGON ((-71.80179 42.24085, -71.80157 42.240...  732700
# 10  POLYGON ((-71.82847 42.24218, -71.82696 42.242...  733000
# 11  POLYGON ((-71.80376 42.24405, -71.80373 42.244...  732600
# 12  POLYGON ((-71.82280 42.24993, -71.82249 42.250...  731300
# 13  POLYGON ((-71.78562 42.25593, -71.78541 42.255...  732302
# 14  MULTIPOLYGON (((-71.73124 42.24129, -71.73147 ...  739101
# 15  POLYGON ((-71.78255 42.25850, -71.78247 42.258...  732202
# 16  POLYGON ((-71.76962 42.27225, -71.76952 42.272...  732201
# 17  POLYGON ((-71.78963 42.27908, -71.78945 42.279...  732002
# 18  POLYGON ((-71.79774 42.28395, -71.79766 42.283...  731900
# 19  POLYGON ((-71.79794 42.28581, -71.79790 42.286...  730402
# 20  POLYGON ((-71.81724 42.29529, -71.81710 42.295...  730500
# 21  POLYGON ((-71.80059 42.28937, -71.80054 42.289...  730401
# 22  POLYGON ((-71.80128 42.30338, -71.80125 42.303...  730300
# 23  POLYGON ((-71.79348 42.32429, -71.79335 42.324...  730200
# 24  POLYGON ((-71.82367 42.31815, -71.82294 42.318...  730100
# 25  POLYGON ((-71.82294 42.31860, -71.82367 42.318...  728200
# 26  POLYGON ((-71.78616 42.34103, -71.78663 42.340...  729200
# 27  POLYGON ((-71.76827 42.31127, -71.76899 42.312...  729100
# 28  POLYGON ((-71.76827 42.31127, -71.76821 42.311...  739500
# 29  POLYGON ((-71.78139 42.31098, -71.78115 42.311...  732001
# 30  POLYGON ((-71.79868 42.21254, -71.79852 42.212...  736500
# 31  MULTIPOLYGON (((-71.83843 42.22848, -71.83819 ...  736300
# 32  MULTIPOLYGON (((-71.85656 42.22669, -71.85653 ...  736200
# 33  POLYGON ((-71.85398 42.22962, -71.85383 42.230...  733101
# 34  POLYGON ((-71.86353 42.24070, -71.86350 42.240...  733102
# 35  POLYGON ((-71.88404 42.28126, -71.88399 42.281...  735200
# 36  POLYGON ((-71.83345 42.24500, -71.83340 42.245...  731204
# 37  POLYGON ((-71.83509 42.24594, -71.83495 42.246...  731203
# 38  POLYGON ((-71.82543 42.25191, -71.82496 42.252...  731202
# 39  POLYGON ((-71.80663 42.25425, -71.80642 42.254...  732500
# 40  POLYGON ((-71.79583 42.25539, -71.79531 42.255...  732400
# 41  POLYGON ((-71.82419 42.25930, -71.82379 42.260...  731400
# 42  POLYGON ((-71.82106 42.26286, -71.82065 42.263...  731500
# 43  POLYGON ((-71.80738 42.25926, -71.80700 42.259...  731700
# 44  POLYGON ((-71.79350 42.25926, -71.79348 42.259...  732203
# 45  POLYGON ((-71.79696 42.26996, -71.79687 42.270...  731802
# 46  POLYGON ((-71.79347 42.26225, -71.79292 42.262...  731801
# 47  POLYGON ((-71.86148 42.25493, -71.86142 42.255...  731002
# 48  POLYGON ((-71.84818 42.26185, -71.84821 42.262...  731101
# 49  POLYGON ((-71.87613 42.26667, -71.87077 42.266...  731001
# 50  POLYGON ((-71.83536 42.26358, -71.83480 42.263...  731102
# 51  POLYGON ((-71.85484 42.27347, -71.85478 42.273...  730902
# 52  POLYGON ((-71.84195 42.27154, -71.84193 42.271...  730901
# 53  POLYGON ((-71.84315 42.27874, -71.84277 42.279...  730802
# 54  POLYGON ((-71.84372 42.28839, -71.84366 42.288...  730801
# 55  POLYGON ((-71.88387 42.28137, -71.88316 42.281...  730700
# 56  POLYGON ((-71.82658 42.31617, -71.82640 42.315...  730600
# 57  MULTIPOLYGON (((-71.87539 42.28655, -71.87667 ...  727100
# 58  POLYGON ((-71.87524 42.28664, -71.87539 42.286...  728100
# 59  POLYGON ((-71.81752 42.26785, -71.81746 42.268...  731600

# %%
import folium

# Create a Folium map
m = folium.Map(location=[42.2626, -71.8023], zoom_start=10)
colormap = LinearColormap(colors=['green', 'white'], vmin=17.7, vmax=88.7)

# Iterate over the rows of the worcesterCensus4326 GeoDataFrame and add polygons to the map with color based on the "Percent White" column
for idx, row in Census4326.iterrows():
    # Check the value of "Percent White" for the current row
    print(f"Census Tract: {row['Tract']}, Percent White: {row['Percent White']}")
    
    # Style function for GeoJSON features
    style_function = lambda x, row=row: {
        'fillColor': colormap(row['Percent White']),
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.7
    }
    # Add GeoJSON feature to the map
    #folium.GeoJson(row.geometry.__geo_interface__, style_function=style_function).add_to(m)
    # Add GeoJSON feature to the map with tooltip showing "Percent White" value
    
    folium.GeoJson(row.geometry.__geo_interface__, 
                   style_function=style_function,
                   tooltip=f"Census Tract: {row['Tract']}<br>Percent White: {row['Percent White']}").add_to(m)
    
#folium.GeoJson(combined_gdf.geometry).add_to(m)
# Display the map
m
# Out:
# Census Tract: 737300, Percent White: 83.8
# Census Tract: 732801, Percent White: 61.3
# Census Tract: 761300, Percent White: 81.9
# Census Tract: 732301, Percent White: 62.5
# Census Tract: 737100, Percent White: 86.9
# Census Tract: 736400, Percent White: 83.6
# Census Tract: 732901, Percent White: 49.4
# Census Tract: 732802, Percent White: 49.0
# Census Tract: 732902, Percent White: 68.9
# Census Tract: 732700, Percent White: 34.1
# Census Tract: 733000, Percent White: 26.3
# Census Tract: 732600, Percent White: 31.2
# Census Tract: 731300, Percent White: 17.7
# Census Tract: 732302, Percent White: 47.6
# Census Tract: 739101, Percent White: 64.1
# Census Tract: 732202, Percent White: 60.0
# Census Tract: 732201, Percent White: 55.6
# Census Tract: 732002, Percent White: 53.7
# Census Tract: 731900, Percent White: 28.8
# Census Tract: 730402, Percent White: 38.6
# Census Tract: 730500, Percent White: 50.0
# Census Tract: 730401, Percent White: 40.3
# Census Tract: 730300, Percent White: 64.6
# Census Tract: 730200, Percent White: 67.9
# Census Tract: 730100, Percent White: 61.8
# Census Tract: 728200, Percent White: 86.6
# Census Tract: 729200, Percent White: 84.5
# Census Tract: 729100, Percent White: 82.2
# Census Tract: 739500, Percent White: 73.0
# Census Tract: 732001, Percent White: 20.2
# Census Tract: 736500, Percent White: 88.7
# Census Tract: 736300, Percent White: 82.6
# Census Tract: 736200, Percent White: 83.8
# Census Tract: 733101, Percent White: 58.5
# Census Tract: 733102, Percent White: 52.1
# Census Tract: 735200, Percent White: 75.6
# Census Tract: 731204, Percent White: 26.5
# Census Tract: 731203, Percent White: 32.9
# Census Tract: 731202, Percent White: 72.4
# Census Tract: 732500, Percent White: 32.6
# Census Tract: 732400, Percent White: 28.4
# Census Tract: 731400, Percent White: 19.4
# Census Tract: 731500, Percent White: 25.3
# Census Tract: 731700, Percent White: 47.7
# Census Tract: 732203, Percent White: 41.3
# Census Tract: 731802, Percent White: 22.5
# Census Tract: 731801, Percent White: 51.7
# Census Tract: 731002, Percent White: 45.9
# Census Tract: 731101, Percent White: 41.4
# Census Tract: 731001, Percent White: 51.1
# Census Tract: 731102, Percent White: 61.7
# Census Tract: 730902, Percent White: 72.3
# Census Tract: 730901, Percent White: 77.4
# Census Tract: 730802, Percent White: 73.7
# Census Tract: 730801, Percent White: 78.6
# Census Tract: 730700, Percent White: 68.1
# Census Tract: 730600, Percent White: 78.5
# Census Tract: 727100, Percent White: 84.9
# Census Tract: 728100, Percent White: 85.3
# Census Tract: 731600, Percent White: 60.73
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08b6a3133d5a42625caf57da0bb7dac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08b6a3133d5a42625caf57da0bb7dac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08b6a3133d5a42625caf57da0bb7dac4 = L.map(
#                 &quot;map_08b6a3133d5a42625caf57da0bb7dac4&quot;,
#                 {
#                     center: [42.2626, -71.8023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b2ca6e5b7c303b57f0325b5876c8048 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8b2ca6e5b7c303b57f0325b5876c8048.addTo(map_08b6a3133d5a42625caf57da0bb7dac4);
#
#
#         function geo_json_5a1252a9c6471e931c51a0a576dffb32_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eef7eeff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5a1252a9c6471e931c51a0a576dffb32_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5a1252a9c6471e931c51a0a576dffb32 = L.geoJson(null, {
#                 onEachFeature: geo_json_5a1252a9c6471e931c51a0a576dffb32_onEachFeature,
#
#                 style: geo_json_5a1252a9c6471e931c51a0a576dffb32_styler,
#         });
#
#         function geo_json_5a1252a9c6471e931c51a0a576dffb32_add (data) {
#             geo_json_5a1252a9c6471e931c51a0a576dffb32
#                 .addData(data);
#         }
#             geo_json_5a1252a9c6471e931c51a0a576dffb32_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.78309681940122, 42.21613962233172], [-71.78310681944697, 42.21620262279509], [-71.78030381884234, 42.217433622764], [-71.78012381891728, 42.217510623000656], [-71.77982581899145, 42.21764262271272], [-71.77891281804905, 42.21804162329479], [-71.77870481853492, 42.218133622974655], [-71.77594781706274, 42.21934262333559], [-71.77520281724817, 42.21966962313908], [-71.76897381552475, 42.22240262434563], [-71.76539581407002, 42.223970624364654], [-71.76519381440364, 42.22405962456522], [-71.76171281303327, 42.22558562487726], [-71.7596538124183, 42.226488625025624], [-71.7519258099466, 42.22987762589546], [-71.75188381011381, 42.22989662622632], [-71.74535680846456, 42.23275862667634], [-71.74523280861601, 42.23281262664228], [-71.74265380741906, 42.23394262720324], [-71.74098780716449, 42.23467162745962], [-71.73885447480468, 42.23560648247541], [-71.74097597066539, 42.23461400102767], [-71.74159797031834, 42.23434700086464], [-71.7422699703127, 42.2340360010065], [-71.74254197000896, 42.2339120001292], [-71.74254197083472, 42.23390999964954], [-71.74530997158564, 42.232711000110164], [-71.74532397164377, 42.23275899967714], [-71.74535697216575, 42.232749999907426], [-71.74670897333273, 42.23215300008089], [-71.74684297272378, 42.232090999626834], [-71.74994897454184, 42.230723998432], [-71.7518439722372, 42.22986800076188], [-71.75192797288058, 42.22984800066914], [-71.75192797219876, 42.229846000190584], [-71.75341297250517, 42.22919900120243], [-71.75511797133295, 42.22844800201157], [-71.75750497001076, 42.227397004656304], [-71.75963497080672, 42.226462006036826], [-71.76169896902145, 42.22555100775981], [-71.76343496746159, 42.224787009199446], [-71.76517296840115, 42.22402001033491], [-71.76537596758116, 42.22393101025454], [-71.76697696655346, 42.22322801084423], [-71.76894996623207, 42.2223640132459], [-71.7709959654451, 42.221459015239574], [-71.77304996470971, 42.22055401545094], [-71.77516596259817, 42.21961901714224], [-71.77592896340668, 42.21928701752739], [-71.77849996140817, 42.218151018960754], [-71.77887896164214, 42.21798801947891], [-71.77981796152874, 42.21757501979271], [-71.78033196037207, 42.21735501984563], [-71.78310121309568, 42.216128896612936], [-71.78309681940122, 42.21613962233172]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_5a1252a9c6471e931c51a0a576dffb32.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract: 737300&lt;br&gt;Percent White: 83.8
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             geo_json_5a1252a9c6471e931c51a0a576dffb32.addTo(map_08b6a3133d5a42625caf57da0bb7dac4);
#
#
#         function geo_json_8fb5a586183d883de0242ca368ccce63_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9dce9dff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};

# %%
# Check the range of values in the "Percent White" column
print(Census4326['Percent White'].describe())
# Out:
# count    60.000000
# mean     57.295500
# std      21.194576
# min      17.700000
# 25%      41.050000
# 50%      60.365000
# 75%      76.050000
# max      88.700000
# Name: Percent White, dtype: float64

# %%
#Census4326.to_csv("wooCensus2020.csv")

# %%
# For this project we are using 32619, so transform the CRS before downloading as .shp file
wooCensus2020 = Census4326.to_crs(epsg=32619)

# %%
wooCensus2020.crs
# Out:
# <Projected CRS: EPSG:32619>
# Name: WGS 84 / UTM zone 19N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 72°W and 66°W, northern hemisphere between equator and 84°N, onshore and offshore. Aruba. Bahamas. Brazil. Canada - New Brunswick (NB); Labrador; Nunavut; Nova Scotia (NS); Quebec. Colombia. Dominican Republic. Greenland. Netherlands Antilles. Puerto Rico. Turks and Caicos Islands. United States. Venezuela.
# - bounds: (-72.0, 0.0, -66.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 19N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
wooCensus2020.to_file("wooCensus2020.shp")
